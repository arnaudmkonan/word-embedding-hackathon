# %% [markdown]
# # Introduction
#
#
# word embeddings are dense vectors that represent words and they are what we use as input to our language models. These embeddings are trained separately than our models on lots of text..that could be text from Wikipedia, from other places on the internet or specialized content, like SPDs.
#
#
# When we train our models we can adjust these embeddings, but it's usually better to freeze them since allowing them to change creates too many flexible parameters and leads us to over-fit easily.
#
#
# If we normalize our text before hand we can control what our word embeddings are eg we could convert words like
# `OOP` to `out of pocket` or whatever we wish, it could be `outofpocket`, as long as we stick to this convention. This tutorial we learn how to creat our own embeddings or word representations.
#
#
# This notebook trains on wikipedia data but eventually we'll collect our own texts with the help of Dani et al. and see how certain terms change!

# %% [markdown]
# # Word Embedding Tutorial: Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
#
# * http://ruder.io/word-embeddings-1/
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# an interesting with improvements:
# * Distributed Representations of Words and Phrases and their Compositionality
# http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:48, 288KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
# NB that words have a natural (meaningful) order as the occur in language and have context..that we'll use later!
words = utils.preprocess(text)

# %%
# NB notice that these are just strings..so we can preprocess our text to any specification we wish!
print(words[:100])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as', 'a', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'the', 'word', 'anarchism', 'is', 'derived', 'from', 'the', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'anarchism', 'as', 'a', 'political', 'philosophy', 'is', 'the', 'belief', 'that', 'rulers', 'are', 'unnecessary', 'and', 'should', 'be', 'abolished', 'although', 'there', 'are', 'differing']

# %%
print("Total words:  {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words:  16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
# the dictionary my be ordered by frequency but the int_word order is same as text
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ### Special Health Care like vocabulary terms we'd like to track

# %%
benefits_terms = ['insurance','maximum','health','medical','coverage','hospital','wellness','vaccination','incentive']
non_benefit_terms = ['car','house','payment','fitness','nutrition','obesity','diabetes','clinic']
print('Benefit terms:')
for i in benefits_terms:
    print('term:', i, 'vocab integer:\t', vocab_to_int[i])
    
print()
print('Non Benefit terms:')
for i in non_benefit_terms:
    print('term:', i, 'vocab integer:\t', vocab_to_int[i])
    
benefits_terms_ints = [vocab_to_int[i] for i in benefits_terms]
non_benefits_terms_ints = [vocab_to_int[i] for i in non_benefit_terms]
# Out:
# Benefit terms:
# term: insurance vocab integer:	 3426
# term: maximum vocab integer:	 2094
# term: health vocab integer:	 863
# term: medical vocab integer:	 916
# term: coverage vocab integer:	 4039
# term: hospital vocab integer:	 2966
# term: wellness vocab integer:	 57101
# term: vaccination vocab integer:	 15206
# term: incentive vocab integer:	 10991
#
# Non Benefit terms:
# term: car vocab integer:	 982
# term: house vocab integer:	 276
# term: payment vocab integer:	 6235
# term: fitness vocab integer:	 10472
# term: nutrition vocab integer:	 9310
# term: obesity vocab integer:	 19712
# term: diabetes vocab integer:	 8539
# term: clinic vocab integer:	 13232

# %%
my_terms = ['american','european']
for i in my_terms:
    print('term:', i, 'vocab integer:\t', vocab_to_int[i])
my_terms_ints = [vocab_to_int[i] for i in my_terms]
# Out:
# term: american vocab integer:	 63
# term: european vocab integer:	 241

# %%
# note that a lot of terms we want are not in the dataset
print('Nice to have terms:')
nice_terms = ['deductible','out-of-pocket','copayment','coinsurance','co-insurance','obamacare','aca','copay']
for i in nice_terms:
    print('term:',i, '\tin set:\t', i in set(words))
# Out:
# Nice to have terms:
# term: deductible 	in set:	 False
# term: out-of-pocket 	in set:	 False
# term: copayment 	in set:	 False
# term: coinsurance 	in set:	 False
# term: co-insurance 	in set:	 False
# term: obamacare 	in set:	 False
# term: aca 	in set:	 False
# term: copay 	in set:	 False

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
random.sample(range(10),4)
# Out:
# [2, 1, 3, 0]

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))
    # add our special terms here
    valid_examples = np.append(valid_examples,benefits_terms_ints)
    valid_examples = np.append(valid_examples,non_benefits_terms_ints)
    valid_examples = np.append(valid_examples,my_terms_ints)
    
    valid_size = valid_size + len(benefits_terms_ints) + len(non_benefits_terms_ints) + len(my_terms_ints)
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6645 0.3617 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6158 0.3573 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5282 0.3591 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5667 0.3548 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5269 0.3555 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5427 0.3559 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5657 0.3761 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5404 0.3770 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4441 0.3598 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4197 0.3628 sec/batch
# Nearest to has: bathroom, robson, cataclysm, eir, colorized, sifre, conifers, omphale,
# Nearest to such: beatification, seif, huntington, impact, implanted, eyed, vukovar, spaced,
# Nearest to between: polemical, suffixes, constitutionality, raccoons, september, rx, changeable, shrub,
# Nearest to some: flirty, bechet, declare, labyrinth, occult, trigonal, skipper, reads,
# Nearest to where: abe, transeau, overruns, depth, nauvoo, dada, gathering, darken,
# Nearest to be: fulfill, tractable, rustam, emptying, danubian, jane, passy, publius,
# Nearest to in: freshly, screenplays, castings, mounds, populous, nervosa, grocery, thawing,
# Nearest to no: circus, mannheim, recapitulation, haryana, although, jewellery, lpga, vechten,
# Nearest to accepted: letterboxer, wash, canidae, gloves, intron, seed, held, undeciphered,
# Nearest to freedom: nascar, execution, perpendicularly, pedrera, tombstone, alias, prostitutes, cartilaginous,
# Nearest to file: branching, cidr, epistemic, dhole, essentials, filial, quotations, dahalo,
# Nearest to resources: pleistocene, compose, cics, osr, phidias, inception, conclusively, gangster,
# Nearest to arts: recompense, adversus, porn, pinguinus, lightened, striping, declaratory, parsis,
# Nearest to taking: monitors, zombie, corrupted, ic, cobb, loess, bourgogne, immersion,
# Nearest to universe: krupskaya, mng, involving, sio, bonnie, nauk, boleslaw, jackals,
# Nearest to mean: abdelkader, speedily, camilla, reemerged, endure, cyg, vinny, slogan,
# Nearest to insurance: diamagnetic, teslas, picker, anaheim, septentrional, howser, nanotechnology, randal,
# Nearest to maximum: woolworth, loner, brutality, kov, puri, failings, vegetables, scrumpy,
# Nearest to health: jet, luanda, chalumeau, flip, boycotted, combinator, fugitive, costumes,
# Nearest to medical: differentiate, malleson, kochi, organizer, catal, dms, chinguetti, rawls,
# Nearest to coverage: assessment, lesion, yetzer, courtney, filmmakers, barter, bermudez, flexible,
# Nearest to hospital: haman, chihuly, infinitude, montrealers, language, figueres, canadensis, julian,
# Nearest to wellness: innkeeper, iud, experimenter, matriculation, jondo, shortwave, reformed, interlanguage,
# Nearest to vaccination: convinced, imperative, vocalised, cmp, retreated, connectionist, amounts, assisted,
# Nearest to incentive: embraced, handicrafts, psychoanalytical, pastor, obstructing, eulogies, rohde, soil,
# Nearest to car: marvelous, anticipate, fuses, plural, coalesce, dass, methodists, xnor,
# Nearest to house: revisits, langevin, deny, mordor, intercalation, bisexuals, scuttled, doonesbury,
# Nearest to payment: livingston, fortuna, syrups, traumatized, drinker, lamb, odyssey, trace,
# Nearest to fitness: pickard, support, franchise, corridor, adrian, assigns, indefatigable, hamsters,
# Nearest to nutrition: lambda, heirs, pentagon, tranquillity, certificates, stabilize, japonica, cip,
# Nearest to obesity: alessandri, isoleucine, attenuation, samaras, reassemble, riso, twisted, prism,
# Nearest to diabetes: northwest, reverting, preston, tiran, koine, lode, bangladeshis, husbandry,
# Nearest to clinic: crackdown, flamsteed, cvn, kor, birdlife, flagg, arabsat, hilberg,
# Nearest to american: earns, topography, container, hefner, extinguished, connections, enormous, katanga,
# Nearest to european: silverstein, excitotoxins, grub, teh, stand, rotations, presume, debating,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4794 0.3745 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3935 0.3614 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3460 0.3829 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2440 0.3556 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1769 0.3582 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1616 0.3560 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0831 0.3528 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0723 0.3607 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0081 0.3592 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9796 0.3597 sec/batch
# Nearest to has: bathroom, cataclysm, stroke, robson, at, deviation, new, conifers,
# Nearest to such: impact, completing, pile, seif, rare, mass, detecting, successful,
# Nearest to between: polemical, september, rites, constitutionality, soviets, finally, obstacles, suffixes,
# Nearest to some: declare, bechet, reads, feral, action, flirty, mathematical, psychologists,
# Nearest to where: have, depth, gathering, historical, principal, override, centered, nauvoo,
# Nearest to be: fulfill, concepts, tractable, emptying, fact, noted, rustam, should,
# Nearest to in: freshly, allows, school, high, aside, step, under, mostly,
# Nearest to no: circus, although, definitions, mannheim, recapitulation, army, situated, opinion,
# Nearest to accepted: letterboxer, wash, held, canidae, park, reputable, combined, organisation,
# Nearest to freedom: nascar, execution, reliable, alias, prostitutes, detailed, tombstone, cartilaginous,
# Nearest to file: cidr, quotations, essentials, epistemic, filial, branching, graduating, camilla,
# Nearest to resources: compose, pleistocene, inception, conclusively, osr, extant, berets, methanol,
# Nearest to arts: recompense, porn, lightened, adversus, striping, declaratory, imperialism, females,
# Nearest to taking: monitors, corrupted, zombie, fruits, ic, relatively, jama, weapons,
# Nearest to universe: involving, bonnie, krupskaya, salt, almanac, breathing, untreated, pantheon,
# Nearest to mean: speedily, cyg, slogan, abdelkader, planes, camilla, victorian, post,
# Nearest to insurance: anaheim, teslas, diamagnetic, nanotechnology, septentrional, generally, randal, robles,
# Nearest to maximum: staff, loner, brutality, woolworth, intact, parties, propositional, failings,
# Nearest to health: jet, chalumeau, separate, boycotted, flip, luanda, combinator, bridgeport,
# Nearest to medical: differentiate, organizer, malleson, catal, downplayed, dms, representatives, glycerol,
# Nearest to coverage: assessment, lesion, flexible, barter, filmmakers, funded, yetzer, courtney,
# Nearest to hospital: haman, language, chihuly, infinitude, figueres, why, whenever, jesus,
# Nearest to wellness: innkeeper, matriculation, iud, experimenter, polished, jondo, shortwave, interlanguage,
# Nearest to vaccination: convinced, imperative, vocalised, cmp, retreated, korps, connectionist, amounts,
# Nearest to incentive: embraced, soil, handicrafts, pastor, psychoanalytical, eulogies, goals, tina,
# Nearest to car: marvelous, plural, anticipate, coalesce, bodies, dass, fuses, records,
# Nearest to house: langevin, deny, revisits, physically, scuttled, successful, pumped, nebula,
# Nearest to payment: livingston, traumatized, fortuna, syrups, odyssey, trace, lamb, ferdinand,
# Nearest to fitness: pickard, support, franchise, assigns, adrian, procure, undisciplined, bureaucrats,
# Nearest to nutrition: lambda, heirs, pentagon, accounts, certificates, tranquillity, jute, nations,
# Nearest to obesity: alessandri, isoleucine, attenuation, reassemble, twisted, prism, samaras, riso,
# Nearest to diabetes: preston, reverting, northwest, tiran, koine, bangladeshis, massey, cadr,
# Nearest to clinic: crackdown, kor, cvn, flamsteed, hilberg, irt, birdlife, flagg,
# Nearest to american: topography, container, extinguished, connections, venezuela, katanga, earns, enormous,
# Nearest to european: silverstein, stand, member, presume, contributed, grub, pc, debating,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9025 0.3655 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9025 0.3600 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8641 0.3592 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8657 0.3558 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8234 0.3545 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7952 0.3560 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7990 0.3570 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7887 0.3574 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7745 0.3551 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7686 0.3569 sec/batch
# Nearest to has: bathroom, cataclysm, stroke, shared, deviation, robson, demographics, informally,
# Nearest to such: impact, detecting, seif, pile, communal, lenovo, huntington, spaced,
# Nearest to between: polemical, september, suffixes, constitutionality, continuous, soviets, ncaa, increasingly,
# Nearest to some: declare, reads, arise, bechet, occult, flirty, psychologists, feral,
# Nearest to where: depth, abe, overruns, have, principal, gathering, override, dada,
# Nearest to be: fulfill, tractable, concepts, noted, rustam, follow, simplicity, emptying,
# Nearest to in: freshly, inevitably, mostly, allows, under, geneva, school, eur,
# Nearest to no: circus, although, opinion, recapitulation, stringent, situated, jewellery, lpga,
# Nearest to accepted: wash, letterboxer, canidae, park, organisation, held, seed, deportation,
# Nearest to freedom: execution, nascar, reliable, tombstone, prostitutes, outcome, alias, detailed,
# Nearest to file: cidr, quotations, incomes, essentials, graduating, branching, camilla, filial,
# Nearest to resources: compose, pleistocene, inception, conclusively, methanol, gangster, berets, bernstein,
# Nearest to arts: porn, lightened, adversus, imperialism, females, recompense, striping, declaratory,
# Nearest to taking: monitors, corrupted, zombie, ic, indoor, ios, fruits, jama,
# Nearest to universe: bonnie, involving, krupskaya, avoided, salt, breathing, inputs, almanac,
# Nearest to mean: endure, speedily, slogan, closure, cyg, camilla, transgender, fingerprint,
# Nearest to insurance: anaheim, nanotechnology, generally, characterize, religions, duchy, septentrional, raging,
# Nearest to maximum: failings, loner, staff, woolworth, fashion, parties, schuster, brutality,
# Nearest to health: jet, chalumeau, boycotted, flip, separate, fugitive, gospel, luanda,
# Nearest to medical: differentiate, organizer, downplayed, endorsement, malleson, nominal, catal, garland,
# Nearest to coverage: assessment, lesion, flexible, filmmakers, barter, funded, lillee, insurers,
# Nearest to hospital: haman, chihuly, language, infinitude, whenever, integration, julian, figueres,
# Nearest to wellness: innkeeper, matriculation, iud, experimenter, polished, jondo, oxides, interlanguage,
# Nearest to vaccination: convinced, imperative, vocalised, retreated, korps, cmp, connectionist, assisted,
# Nearest to incentive: embraced, handicrafts, soil, pastor, psychoanalytical, eulogies, grounded, rohde,
# Nearest to car: marvelous, anticipate, fuses, plural, dass, coalesce, methodists, bodies,
# Nearest to house: deny, revisits, langevin, scuttled, successful, nebula, kernel, newsmagazine,
# Nearest to payment: livingston, traumatized, trace, fortuna, syrups, odyssey, dvd, lamb,
# Nearest to fitness: pickard, support, franchise, procure, assigns, recurs, adrian, disdain,
# Nearest to nutrition: lambda, heirs, pentagon, accounts, certificates, tranquillity, stabilize, nations,
# Nearest to obesity: alessandri, isoleucine, attenuation, twisted, reassemble, conscientious, samaras, prism,
# Nearest to diabetes: preston, bangladeshis, northwest, massey, koine, reverting, yoho, londoners,
# Nearest to clinic: crackdown, kor, irt, hilberg, cvn, fisc, flamsteed, arabsat,
# Nearest to american: venezuela, topography, earns, happening, extinguished, katanga, connections, initiating,
# Nearest to european: silverstein, presume, member, debating, grub, stand, contributed, rotations,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8010 0.3621 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7340 0.3550 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7307 0.3571 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7441 0.3676 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7311 0.3755 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6774 0.3793 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7025 0.3727 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7383 0.3738 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7097 0.3697 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6302 0.3603 sec/batch
# Nearest to has: bathroom, stroke, cataclysm, conifers, robson, backfield, deviation, demographics,
# Nearest to such: lenovo, impact, detecting, spaced, demarcation, seif, pile, communal,
# Nearest to between: polemical, suffixes, constitutionality, soviets, continuous, september, ncaa, delegated,
# Nearest to some: declare, reads, bechet, arise, flirty, occult, bridging, skipper,
# Nearest to where: abe, depth, principal, have, gathering, override, overruns, dada,
# Nearest to be: tractable, fulfill, concepts, rustam, noted, simplicity, follow, involve,
# Nearest to in: mostly, under, freshly, geneva, bourbon, bf, fouch, nonprofit,
# Nearest to no: circus, although, stringent, opinion, jewellery, wherever, lpga, onerous,
# Nearest to accepted: letterboxer, canidae, held, wash, reputable, deportation, park, organisation,
# Nearest to freedom: nascar, execution, tombstone, perpendicularly, cartilaginous, reliable, prostitutes, alias,
# Nearest to file: cidr, incomes, epistemic, camilla, essentials, branching, quotations, filial,
# Nearest to resources: compose, pleistocene, conclusively, inception, gangster, berets, methanol, bernstein,
# Nearest to arts: porn, declaratory, lightened, imperialism, adversus, recompense, bombardment, females,
# Nearest to taking: monitors, corrupted, zombie, cobb, ic, loess, immersion, fruits,
# Nearest to universe: krupskaya, bonnie, involving, avoided, breathing, sio, inputs, untreated,
# Nearest to mean: endure, speedily, camilla, abdelkader, cyg, revolves, closure, vinny,
# Nearest to insurance: anaheim, generally, nanotechnology, religions, transition, characterize, duchy, raging,
# Nearest to maximum: failings, woolworth, loner, vegetables, staff, aficionados, complementary, schuster,
# Nearest to health: jet, chalumeau, boycotted, combinator, distaste, flip, luanda, bridgeport,
# Nearest to medical: differentiate, endorsement, malleson, organizer, chinguetti, catal, hanafi, designates,
# Nearest to coverage: assessment, barter, lesion, flexible, filmmakers, courtney, insurers, semicolon,
# Nearest to hospital: haman, convening, chihuly, whenever, infinitude, figueres, parachute, librarians,
# Nearest to wellness: innkeeper, matriculation, iud, experimenter, polished, interlanguage, jondo, oxides,
# Nearest to vaccination: convinced, imperative, vocalised, retreated, korps, cmp, connectionist, assisted,
# Nearest to incentive: embraced, handicrafts, psychoanalytical, pastor, soil, obstructing, eulogies, misspelled,
# Nearest to car: marvelous, fuses, anticipate, methodists, coalesce, dass, bees, plural,
# Nearest to house: deny, revisits, langevin, newsmagazine, intercalation, scuttled, bisexuals, seaboard,
# Nearest to payment: livingston, traumatized, odyssey, fortuna, syrups, lamb, legends, genuine,
# Nearest to fitness: pickard, franchise, procure, support, adrian, assigns, bureaucrats, disdain,
# Nearest to nutrition: lambda, heirs, pentagon, certificates, accounts, tranquillity, stabilize, cip,
# Nearest to obesity: alessandri, isoleucine, attenuation, twisted, reassemble, samaras, conscientious, prism,
# Nearest to diabetes: massey, bangladeshis, koine, londoners, northwest, yoho, cadr, preston,
# Nearest to clinic: crackdown, kor, irt, hilberg, delivers, cvn, fisc, piron,
# Nearest to american: venezuela, topography, earns, lott, nassau, states, concordia, happening,
# Nearest to european: silverstein, member, presume, debating, grub, contributed, vilnius, bahmani,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6611 0.3596 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6565 0.3532 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6278 0.3570 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6167 0.3576 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6177 0.3558 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6439 0.3558 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5951 0.2623 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5528 0.3561 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5267 0.3569 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5048 0.3563 sec/batch
# Nearest to has: bathroom, stroke, conifers, demographics, cataclysm, deviation, robson, circumscription,
# Nearest to such: lenovo, detecting, seif, impact, geometrical, spaced, subsurface, demarcation,
# Nearest to between: polemical, suffixes, constitutionality, continuous, soviets, changeable, shrub, delegated,
# Nearest to some: bridging, declare, flirty, arise, congruent, reads, sight, andreyev,
# Nearest to where: abe, principal, depth, gathering, have, dada, overruns, darken,
# Nearest to be: concepts, tractable, involve, fulfill, rustam, fact, simplicity, follow,
# Nearest to in: freshly, traction, mostly, eur, bourbon, under, bf, fouch,
# Nearest to no: although, circus, stringent, opinion, jewellery, wherever, onerous, immobile,
# Nearest to accepted: letterboxer, canidae, wash, deportation, held, seed, reputable, reverted,
# Nearest to freedom: nascar, execution, tombstone, perpendicularly, cartilaginous, detailed, reliable, outcome,
# Nearest to file: incomes, branching, cidr, epistemic, camilla, essentials, wrestling, filial,
# Nearest to resources: pleistocene, compose, conclusively, inception, berets, gangster, negatives, phidias,
# Nearest to arts: lightened, porn, declaratory, recompense, adversus, imperialism, consigned, roadway,
# Nearest to taking: monitors, corrupted, immersion, cobb, loess, zombie, ic, acre,
# Nearest to universe: involving, krupskaya, sio, bonnie, mng, avoided, inputs, breathing,
# Nearest to mean: endure, speedily, abdelkader, cyg, mathematical, vinny, closure, emergencies,
# Nearest to insurance: anaheim, religions, generally, teslas, transition, septentrional, nanotechnology, randal,
# Nearest to maximum: failings, woolworth, loner, rho, vegetables, complementary, propositional, aficionados,
# Nearest to health: jet, chalumeau, distaste, boycotted, luanda, naoh, combinator, anthropic,
# Nearest to medical: differentiate, malleson, endorsement, catal, organizer, chinguetti, hanafi, designates,
# Nearest to coverage: assessment, barter, flexible, lesion, filmmakers, courtney, vannevar, funded,
# Nearest to hospital: haman, whenever, infinitude, figueres, chihuly, librarians, convening, wilkinson,
# Nearest to wellness: matriculation, innkeeper, iud, experimenter, polished, interlanguage, disputes, procurement,
# Nearest to vaccination: convinced, imperative, vocalised, korps, retreated, amounts, cmp, monotheisms,
# Nearest to incentive: embraced, handicrafts, psychoanalytical, obstructing, soil, eulogies, pastor, misspelled,
# Nearest to car: marvelous, fuses, anticipate, coalesce, dass, bees, warmia, gurps,
# Nearest to house: revisits, langevin, deny, newsmagazine, bisexuals, intercalation, geary, successful,
# Nearest to payment: livingston, traumatized, fortuna, syrups, lamb, genuine, overtly, indent,
# Nearest to fitness: pickard, franchise, procure, adrian, recurs, support, bureaucrats, assigns,
# Nearest to nutrition: lambda, certificates, heirs, pentagon, tranquillity, accounts, cip, stabilize,
# Nearest to obesity: alessandri, isoleucine, attenuation, reassemble, twisted, bohr, prism, aroused,
# Nearest to diabetes: massey, bangladeshis, londoners, koine, cadr, reverting, husbandry, yoho,
# Nearest to clinic: crackdown, kor, irt, hilberg, delivers, fisc, cvn, birdlife,
# Nearest to american: chemist, venezuela, french, poet, activist, footballer, concordia, nassau,
# Nearest to european: member, silverstein, presume, debating, grub, bahmani, contributed, vilnius,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5021 0.3627 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4724 0.3542 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4652 0.3556 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5089 0.3530 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5173 0.3553 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4722 0.3538 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4598 0.3558 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4036 0.3544 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4328 0.3563 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4401 0.3542 sec/batch
# Nearest to has: bathroom, conifers, deviation, stroke, peloponnesian, biathlete, spacey, backfield,
# Nearest to such: lenovo, detecting, impact, seif, subsurface, pile, spaced, geometrical,
# Nearest to between: polemical, suffixes, continuous, constitutionality, soviets, shrub, marketplace, paraded,
# Nearest to some: bridging, arise, declare, andreyev, reads, comprehended, sight, flirty,
# Nearest to where: abe, principal, overruns, gathering, depth, dada, hydrodynamic, transeau,
# Nearest to be: tractable, concepts, involve, rustam, follow, fact, simplicity, fulfill,
# Nearest to in: freshly, nonprofit, mostly, manat, populous, mounds, underpinnings, eur,
# Nearest to no: stringent, although, opinion, circus, jewellery, categories, recapitulation, wherever,
# Nearest to accepted: letterboxer, canidae, wash, held, deportation, reverted, reputable, seed,
# Nearest to freedom: nascar, execution, perpendicularly, tombstone, cartilaginous, detailed, alias, outcome,
# Nearest to file: epistemic, branching, incomes, operating, cidr, wrestling, essentials, endianness,
# Nearest to resources: pleistocene, compose, conclusively, inception, berets, negatives, methanol, phidias,
# Nearest to arts: lightened, porn, declaratory, recompense, adversus, consigned, collectivit, imperialism,
# Nearest to taking: monitors, corrupted, loess, immersion, cobb, acre, zombie, bourgogne,
# Nearest to universe: krupskaya, involving, sio, bonnie, mng, inputs, breathing, avoided,
# Nearest to mean: endure, closure, mathematical, vinny, abdelkader, cyg, speedily, cumulative,
# Nearest to insurance: anaheim, religions, transition, teslas, randal, diamagnetic, septentrional, nanotechnology,
# Nearest to maximum: failings, woolworth, rho, propositional, complementary, loner, puri, vegetables,
# Nearest to health: naoh, distaste, jet, chalumeau, luanda, morel, boycotted, anthropic,
# Nearest to medical: differentiate, malleson, endorsement, catal, designates, chinguetti, latex, hanafi,
# Nearest to coverage: assessment, lesion, barter, filmmakers, flexible, courtney, vannevar, funded,
# Nearest to hospital: haman, figueres, whenever, convening, chihuly, infinitude, librarians, barnstorming,
# Nearest to wellness: innkeeper, matriculation, iud, experimenter, polished, procurement, interlanguage, sinn,
# Nearest to vaccination: convinced, imperative, vocalised, korps, retreated, monotheisms, amounts, aquino,
# Nearest to incentive: embraced, psychoanalytical, handicrafts, obstructing, pastor, chaff, piecewise, soil,
# Nearest to car: marvelous, fuses, anticipate, dass, coalesce, evangelium, gurps, warmia,
# Nearest to house: revisits, langevin, deny, newsmagazine, bisexuals, vice, governor, seaboard,
# Nearest to payment: livingston, fortuna, traumatized, syrups, indent, lamb, overtly, genuine,
# Nearest to fitness: pickard, franchise, procure, adrian, indefatigable, recurs, disdain, assigns,
# Nearest to nutrition: lambda, certificates, tranquillity, accounts, cip, pentagon, imperialistic, stabilize,
# Nearest to obesity: alessandri, isoleucine, reassemble, twisted, attenuation, prism, tombs, catalyzing,
# Nearest to diabetes: bangladeshis, massey, cadr, koine, londoners, reverting, doraemons, husbandry,
# Nearest to clinic: crackdown, kor, irt, hilberg, cvn, delivers, fisc, welcome,
# Nearest to american: venezuela, activist, nbc, concordia, nassau, earns, topography, chemist,
# Nearest to european: member, presume, debating, bahmani, silverstein, grub, excitotoxins, southampton,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4421 0.3612 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4209 0.3523 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4387 0.3542 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3945 0.3551 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4216 0.3524 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4219 0.3564 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3976 0.3548 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3769 0.3533 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4272 0.3538 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3875 0.3571 sec/batch
# Nearest to has: bathroom, conifers, deviation, backfield, spacey, cataclysm, demographics, biathlete,
# Nearest to such: detecting, seif, lenovo, geometrical, subsurface, impact, spaced, pile,
# Nearest to between: polemical, suffixes, constitutionality, continuous, letterpress, soviets, paraded, shrub,
# Nearest to some: arise, bridging, declare, reads, sight, andreyev, comprehended, caveat,
# Nearest to where: abe, dada, hydrodynamic, gathering, overruns, principal, transeau, depth,
# Nearest to be: tractable, concepts, simplicity, rustam, involve, follow, noted, fact,
# Nearest to in: shin, nonprofit, fouch, underpinnings, nervosa, bourbon, cavalrymen, het,
# Nearest to no: although, stringent, opinion, circus, jewellery, categories, recapitulation, wherever,
# Nearest to accepted: letterboxer, wash, canidae, reputable, deportation, clp, rejection, reverted,
# Nearest to freedom: execution, nascar, tombstone, perpendicularly, detailed, outcome, cartilaginous, reliable,
# Nearest to file: operating, incomes, epistemic, database, branching, codepages, endianness, forfeits,
# Nearest to resources: pleistocene, conclusively, compose, inception, berets, methanol, phidias, atolls,
# Nearest to arts: lightened, porn, declaratory, recompense, adversus, roadway, collectivit, emerson,
# Nearest to taking: monitors, loess, corrupted, acre, immersion, porphyrin, zombie, cobb,
# Nearest to universe: krupskaya, involving, sio, bonnie, mng, inputs, avoided, tensor,
# Nearest to mean: endure, abdelkader, explain, closure, speedily, mathematical, herbivore, vinny,
# Nearest to insurance: anaheim, religions, transition, septentrional, teslas, diamagnetic, randal, marketing,
# Nearest to maximum: complementary, woolworth, rho, photosynthesis, failings, cir, propositional, edits,
# Nearest to health: distaste, jet, severe, naoh, morel, boycotted, luanda, anthropic,
# Nearest to medical: differentiate, endorsement, malleson, latex, treatment, chinguetti, sufferers, catal,
# Nearest to coverage: assessment, lesion, barter, flexible, filmmakers, courtney, vannevar, funded,
# Nearest to hospital: haman, infinitude, chihuly, figueres, convening, rebecca, barnstorming, transcaucasian,
# Nearest to wellness: innkeeper, matriculation, iud, polished, experimenter, interlanguage, procurement, reprieve,
# Nearest to vaccination: convinced, imperative, vocalised, korps, amounts, monotheisms, connectionist, conditional,
# Nearest to incentive: embraced, psychoanalytical, handicrafts, obstructing, chaff, soil, piecewise, goals,
# Nearest to car: marvelous, fuses, anticipate, dass, evangelium, gurps, revolvers, warmia,
# Nearest to house: revisits, langevin, deny, bisexuals, governor, donne, newsmagazine, geary,
# Nearest to payment: livingston, fortuna, indent, traumatized, syrups, overtly, genuine, lamb,
# Nearest to fitness: pickard, kazimierz, feeding, indefatigable, assigns, procure, discursive, gallons,
# Nearest to nutrition: lambda, accounts, certificates, cip, stennis, imperialistic, tranquillity, stabilize,
# Nearest to obesity: alessandri, isoleucine, twisted, reassemble, attenuation, prism, catalyzing, esters,
# Nearest to diabetes: bangladeshis, massey, cadr, doraemons, husbandry, londoners, reverting, psychologists,
# Nearest to clinic: crackdown, kor, irt, cvn, fisc, welcome, piron, birdlife,
# Nearest to american: activist, nbc, chemist, earns, concordia, wild, venezuela, swiss,
# Nearest to european: member, debating, silverstein, bahmani, governments, presume, southampton, excitotoxins,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3746 0.3627 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3785 0.3526 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3421 0.3573 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3534 0.3538 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3954 0.3562 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3787 0.3539 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3870 0.3535 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3701 0.3583 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2991 0.3540 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3309 0.3522 sec/batch
# Nearest to has: bathroom, conifers, backfield, demographics, biathlete, shared, deviation, spacey,
# Nearest to such: lenovo, detecting, seif, geometrical, hertz, subsurface, spaced, impact,
# Nearest to between: polemical, suffixes, continuous, constitutionality, soviets, changeable, letterpress, paraded,
# Nearest to some: bridging, arise, comprehended, sight, subdirectories, andreyev, declare, caveat,
# Nearest to where: abe, hydrodynamic, gathering, dada, principal, transeau, overruns, bluish,
# Nearest to be: tractable, concepts, simplicity, noted, follow, involve, rustam, suggesting,
# Nearest to in: nonprofit, fouch, fedayeen, nervosa, mounds, populous, underpinnings, shin,
# Nearest to no: although, stringent, opinion, categories, circus, rif, recapitulation, onerous,
# Nearest to accepted: letterboxer, deportation, canidae, wash, reputable, clp, held, chojn,
# Nearest to freedom: execution, tombstone, nascar, outcome, cartilaginous, detailed, perpendicularly, sensations,
# Nearest to file: operating, database, codepages, branching, lite, endianness, epistemic, incomes,
# Nearest to resources: conclusively, pleistocene, inception, compose, berets, atolls, methanol, cabbages,
# Nearest to arts: lightened, porn, declaratory, roadway, collectivit, advanced, emerson, foundation,
# Nearest to taking: monitors, loess, corrupted, zombie, immersion, porphyrin, extinguishing, cobb,
# Nearest to universe: krupskaya, involving, bonnie, tensor, sio, breathing, inputs, mng,
# Nearest to mean: endure, mathematical, abdelkader, herbivore, explain, closure, vinny, speedily,
# Nearest to insurance: religions, anaheim, transition, septentrional, mollusks, marketing, duchy, teslas,
# Nearest to maximum: woolworth, rho, failings, deployment, upwelling, complementary, hamper, photosynthesis,
# Nearest to health: distaste, boycotted, severe, morel, naoh, chalumeau, jet, topper,
# Nearest to medical: differentiate, endorsement, malleson, treatment, chinguetti, latex, representatives, sufferers,
# Nearest to coverage: assessment, lesion, barter, filmmakers, flexible, courtney, funded, vannevar,
# Nearest to hospital: haman, convening, chihuly, rebecca, figueres, infinitude, barnstorming, transcaucasian,
# Nearest to wellness: innkeeper, matriculation, iud, polished, experimenter, reprieve, interlanguage, suicidal,
# Nearest to vaccination: convinced, imperative, vocalised, conditional, korps, amounts, retreated, monotheisms,
# Nearest to incentive: psychoanalytical, obstructing, handicrafts, embraced, piecewise, chaff, soil, goals,
# Nearest to car: marvelous, fuses, anticipate, dass, evangelium, gurps, revolvers, warmia,
# Nearest to house: revisits, governor, langevin, scuttled, donne, bisexuals, deny, vice,
# Nearest to payment: livingston, fortuna, syrups, traumatized, indent, overtly, hershey, azad,
# Nearest to fitness: pickard, kazimierz, indefatigable, feeding, assigns, bystander, gallons, discursive,
# Nearest to nutrition: lambda, accounts, cip, stennis, certificates, imperialistic, chromosomes, tranquillity,
# Nearest to obesity: alessandri, isoleucine, reassemble, twisted, attenuation, catalyzing, prism, esters,
# Nearest to diabetes: doraemons, bangladeshis, blood, husbandry, pneumoniae, clinically, cadr, massey,
# Nearest to clinic: crackdown, kor, cvn, irt, welcome, fisc, piron, birdlife,
# Nearest to american: activist, nbc, earns, concordia, basketball, physiologist, wild, venezuela,
# Nearest to european: member, bahmani, debating, presume, governments, silverstein, excitotoxins, contributed,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3570 0.3624 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2704 0.3570 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3965 0.3546 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3744 0.3558 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3931 0.3559 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2889 0.3558 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3332 0.3527 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3321 0.3575 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2052 0.3557 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2985 0.3552 sec/batch
# Nearest to has: bathroom, backfield, conifers, circumscription, biathlete, demographics, spacey, friuli,
# Nearest to such: lenovo, seif, geometrical, hertz, spaced, detecting, megabytes, impact,
# Nearest to between: suffixes, polemical, constitutionality, continuous, soviets, changeable, letterpress, cnbc,
# Nearest to some: bridging, comprehended, practice, arise, dalglish, subdirectories, andreyev, caveat,
# Nearest to where: abe, dada, gathering, hydrodynamic, principal, transeau, enjoyed, nauvoo,
# Nearest to be: tractable, concepts, simplicity, rustam, follow, involve, isomorphism, rigorous,
# Nearest to in: fouch, highly, fedayeen, underpinnings, nonprofit, eur, barrymore, cavalrymen,
# Nearest to no: stringent, although, circus, opinion, rif, rudi, recapitulation, categories,
# Nearest to accepted: letterboxer, deportation, canidae, chojn, wash, reputable, clp, held,
# Nearest to freedom: execution, tombstone, outcome, nascar, detailed, cartilaginous, sensations, reliable,
# Nearest to file: database, operating, lite, wrestling, hello, codepages, incomes, epistemic,
# Nearest to resources: pleistocene, conclusively, inception, compose, methanol, berets, cabbages, apocalypses,
# Nearest to arts: lightened, porn, declaratory, advanced, foundation, roadway, recompense, collectivit,
# Nearest to taking: monitors, loess, porphyrin, corrupted, cobb, zombie, acre, synchronised,
# Nearest to universe: krupskaya, involving, tensor, bonnie, omitted, pantheon, jackals, mng,
# Nearest to mean: endure, closure, abdelkader, vint, mathematical, cyg, vinny, herbivore,
# Nearest to insurance: religions, anaheim, marketing, septentrional, mollusks, transition, teslas, duchy,
# Nearest to maximum: woolworth, deployment, upwelling, failings, hamper, complementary, rho, cir,
# Nearest to health: distaste, morel, boycotted, severe, naoh, chalumeau, topper, jet,
# Nearest to medical: differentiate, treatment, endorsement, latex, chinguetti, malleson, sufferers, specialities,
# Nearest to coverage: assessment, lesion, barter, filmmakers, flexible, funded, courtney, vannevar,
# Nearest to hospital: haman, transcaucasian, chihuly, barnstorming, librarians, rebecca, remediation, convening,
# Nearest to wellness: innkeeper, matriculation, iud, experimenter, obstetrics, interlanguage, suicidal, reprieve,
# Nearest to vaccination: imperative, convinced, vocalised, korps, conditional, amounts, monotheisms, retreated,
# Nearest to incentive: psychoanalytical, embraced, obstructing, piecewise, handicrafts, chaff, goals, soil,
# Nearest to car: marvelous, fuses, anticipate, dass, warmia, gurps, evangelium, records,
# Nearest to house: revisits, donne, governor, bisexuals, langevin, vice, deny, revocation,
# Nearest to payment: livingston, fortuna, indent, traumatized, syrups, overtly, azad, hershey,
# Nearest to fitness: pickard, kazimierz, indefatigable, feeding, procure, bystander, eliminative, assigns,
# Nearest to nutrition: lambda, accounts, stabilize, chromosomes, cip, certificates, tranquillity, stennis,
# Nearest to obesity: alessandri, isoleucine, attenuation, diagnosed, twisted, prism, reassemble, catalyzing,
# Nearest to diabetes: doraemons, cadr, blood, clinically, bangladeshis, husbandry, pneumoniae, liver,
# Nearest to clinic: crackdown, kor, irt, cvn, welcome, birdlife, piron, fisc,
# Nearest to american: activist, physiologist, footballer, chemist, nbc, photographer, basketball, baseball,
# Nearest to european: member, bahmani, debating, grub, presume, governments, silverstein, contributed,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3129 0.3624 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2863 0.3606 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3248 0.1664 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2849 0.3642 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2522 0.3739 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2239 0.3585 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2334 0.3570 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2248 0.3595 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1926 0.3564 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2046 0.3556 sec/batch
# Nearest to has: bathroom, demographics, conifers, spacey, biathlete, friuli, circumscription, changes,
# Nearest to such: lenovo, seif, geometrical, hertz, subsurface, aspirant, megabytes, spaced,
# Nearest to between: suffixes, polemical, continuous, constitutionality, soviets, changeable, letterpress, cnbc,
# Nearest to some: bridging, comprehended, arise, dalglish, declare, subdirectories, practice, agnetha,
# Nearest to where: abe, hydrodynamic, principal, gathering, enjoyed, dada, transeau, eddies,
# Nearest to be: tractable, concepts, rustam, involve, noted, simplicity, quadratic, imprisonment,
# Nearest to in: fedayeen, fouch, nonprofit, barrymore, highly, bourbon, populous, manat,
# Nearest to no: stringent, opinion, circus, although, rif, categories, jewellery, recapitulation,
# Nearest to accepted: letterboxer, deportation, canidae, chojn, clp, wash, staying, steeped,
# Nearest to freedom: execution, tombstone, outcome, detailed, nascar, perpendicularly, cartilaginous, reliable,
# Nearest to file: operating, database, lite, endianness, wrestling, codepages, incomes, essentials,
# Nearest to resources: pleistocene, inception, conclusively, compose, apocalypses, atolls, methanol, cabbages,
# Nearest to arts: lightened, declaratory, porn, foundation, advanced, roadway, krzyzewski, recompense,
# Nearest to taking: loess, monitors, babylon, acre, cobb, ijtihad, porphyrin, zombie,
# Nearest to universe: krupskaya, involving, bonnie, omitted, cosmology, tensor, comme, pantheon,
# Nearest to mean: endure, closure, vint, abdelkader, herbivore, intermingled, herbicides, adamantium,
# Nearest to insurance: marketing, anaheim, religions, mollusks, septentrional, transition, price, consumer,
# Nearest to maximum: woolworth, upwelling, hamper, deployment, suse, failings, photosynthesis, nacional,
# Nearest to health: severe, morel, prevention, distaste, meninges, infectious, pathology, trauma,
# Nearest to medical: differentiate, treatment, endorsement, chinguetti, latex, malleson, sufferers, hessen,
# Nearest to coverage: assessment, barter, filmmakers, lesion, flexible, vannevar, funded, menzies,
# Nearest to hospital: transcaucasian, remediation, librarians, haman, bergamo, barnstorming, rebecca, chihuly,
# Nearest to wellness: matriculation, innkeeper, iud, experimenter, interlanguage, obstetrics, suicidal, efficacy,
# Nearest to vaccination: convinced, imperative, vocalised, conditional, korps, amounts, dyson, monotheisms,
# Nearest to incentive: psychoanalytical, embraced, obstructing, piecewise, handicrafts, chaff, goals, soil,
# Nearest to car: marvelous, fuses, cars, prix, manufacturer, gurps, dass, records,
# Nearest to house: revisits, donne, langevin, governor, bisexuals, advert, vice, revocation,
# Nearest to payment: traumatized, fortuna, indent, livingston, syrups, overtly, azad, cheaper,
# Nearest to fitness: pickard, kazimierz, feeding, bystander, disdain, eliminative, indefatigable, procure,
# Nearest to nutrition: lambda, accounts, stabilize, chromosomes, certificates, schistosomiasis, tranquillity, tests,
# Nearest to obesity: alessandri, isoleucine, reassemble, diagnosed, catalyzing, attenuation, prism, twisted,
# Nearest to diabetes: doraemons, pneumoniae, blood, liver, husbandry, psychologists, clinically, cadr,
# Nearest to clinic: crackdown, kor, irt, cvn, fisc, piron, birdlife, midyear,
# Nearest to american: activist, physiologist, nbc, earns, footballer, chemist, basketball, photographer,
# Nearest to european: member, debating, bahmani, presume, grub, contributed, excitotoxins, listed,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2562 0.3639 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2088 0.3576 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2258 0.3600 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1205 0.3590 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1817 0.3578 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1491 0.3529 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1891 0.3549 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1917 0.3557 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1911 0.3570 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1784 0.3546 sec/batch
# Nearest to has: bathroom, conifers, spacey, welsh, punches, baywatch, concertina, circumscription,
# Nearest to such: lenovo, geometrical, seif, detecting, aspirant, subsurface, hertz, megabytes,
# Nearest to between: suffixes, polemical, continuous, letterpress, constitutionality, soviets, changeable, cosmological,
# Nearest to some: practice, bridging, arise, dalglish, declare, comprehended, restrict, custom,
# Nearest to where: abe, gathering, principal, hydrodynamic, transeau, dada, eddies, enjoyed,
# Nearest to be: tractable, concepts, involve, rustam, noted, simplicity, legumes, follow,
# Nearest to in: fedayeen, highly, fouch, barrymore, nonprofit, underpinnings, superhuman, nervosa,
# Nearest to no: stringent, categories, opinion, rif, jewellery, although, circus, immobile,
# Nearest to accepted: letterboxer, canidae, reputable, staying, reject, chojn, rejection, ranging,
# Nearest to freedom: execution, nascar, outcome, detailed, tombstone, sensations, academic, reliable,
# Nearest to file: endianness, database, operating, epistemic, lite, wrestling, cidr, contents,
# Nearest to resources: pleistocene, inception, conclusively, cabbages, methanol, compose, apocalypses, berets,
# Nearest to arts: lightened, porn, declaratory, foundation, krzyzewski, advanced, recompense, emerson,
# Nearest to taking: monitors, loess, porphyrin, acre, funding, babylon, events, zombie,
# Nearest to universe: cosmology, krupskaya, tensor, comme, involving, omitted, pentagram, breathing,
# Nearest to mean: endure, closure, vint, herbivore, abdelkader, epona, herbicides, adamantium,
# Nearest to insurance: marketing, anaheim, religions, mollusks, septentrional, transition, consumer, price,
# Nearest to maximum: upwelling, woolworth, suse, hamper, fructose, cir, deployment, rho,
# Nearest to health: prevention, severe, morel, infectious, pathology, meninges, research, distaste,
# Nearest to medical: differentiate, treatment, endorsement, latex, sufferers, malleson, chinguetti, specialities,
# Nearest to coverage: assessment, filmmakers, barter, lesion, flexible, fan, courtney, hymnals,
# Nearest to hospital: transcaucasian, remediation, librarians, bergamo, barnstorming, rebecca, whenever, chihuly,
# Nearest to wellness: innkeeper, matriculation, iud, suicidal, experimenter, interlanguage, sane, efficacy,
# Nearest to vaccination: convinced, vocalised, imperative, conditional, amounts, korps, synapses, freedb,
# Nearest to incentive: psychoanalytical, obstructing, embraced, piecewise, handicrafts, goals, chaff, bows,
# Nearest to car: marvelous, fuses, cars, prix, vehicle, launcher, tx, manufacturer,
# Nearest to house: revisits, donne, revocation, langevin, bisexuals, advert, governor, scuttled,
# Nearest to payment: traumatized, indent, fortuna, syrups, overtly, livingston, cheaper, azad,
# Nearest to fitness: kazimierz, pickard, feeding, bystander, procure, eliminative, disdain, indefatigable,
# Nearest to nutrition: lambda, accounts, schistosomiasis, certificates, chromosomes, tests, stabilize, stennis,
# Nearest to obesity: isoleucine, alessandri, diagnosed, catalyzing, prism, attenuation, reassemble, bourgeoisie,
# Nearest to diabetes: pneumoniae, doraemons, liver, psychologists, clinically, cadr, migraine, husbandry,
# Nearest to clinic: crackdown, kor, cvn, irt, fisc, birdlife, famine, midyear,
# Nearest to american: activist, nbc, physiologist, earns, hefner, concordia, laurentiis, decoys,
# Nearest to european: member, debating, bahmani, listed, contributed, presume, excitotoxins, silverstein,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1932 0.3593 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2215 0.3602 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1809 0.3560 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1742 0.3533 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1872 0.3539 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1830 0.3554 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2175 0.3603 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1198 0.3555 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1489 0.3706 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1999 0.3640 sec/batch
# Nearest to has: bathroom, conifers, demographics, mcnally, spacey, friuli, ada, welsh,
# Nearest to such: lenovo, aspirant, subsurface, geometrical, seif, universalism, detecting, unfashionable,
# Nearest to between: suffixes, polemical, continuous, letterpress, the, changeable, cosmological, constitutionality,
# Nearest to some: comprehended, bridging, practice, dalglish, disagree, caveat, subdirectories, mechanosynthesis,
# Nearest to where: abe, hydrodynamic, principal, dada, transeau, enjoyed, gathering, eddies,
# Nearest to be: tractable, noted, involve, concepts, imprisonment, rustam, simplicity, suggesting,
# Nearest to in: highly, fouch, barrymore, conclave, underpinnings, fedayeen, bourbon, nonprofit,
# Nearest to no: categories, stringent, although, rif, circus, opinion, immobile, jewellery,
# Nearest to accepted: letterboxer, canidae, staying, ranging, chojn, strabo, reputable, einhard,
# Nearest to freedom: execution, detailed, tombstone, outcome, nascar, sensations, freedoms, reliable,
# Nearest to file: endianness, operating, contents, epistemic, database, lite, extensible, essentials,
# Nearest to resources: pleistocene, inception, cabbages, berets, conclusively, methanol, compose, apocalypses,
# Nearest to arts: lightened, porn, foundation, declaratory, krzyzewski, emerson, advanced, roadway,
# Nearest to taking: monitors, loess, porphyrin, acre, babylon, funding, thither, immersion,
# Nearest to universe: cosmology, krupskaya, cosmological, involving, tensor, omitted, comme, pentagram,
# Nearest to mean: endure, herbivore, abdelkader, closure, vint, adamantium, solstices, cumulative,
# ...
# Nearest to such: characterise, humanist, or, most, often, known, rare, lenovo,
# Nearest to between: polemical, the, suffixes, following, miniscule, lows, continuous, frisia,
# Nearest to some: as, the, also, and, well, rhyming, to, maji,
# Nearest to where: lim, displeased, quang, dada, gathering, hydrodynamic, aurelianus, daughter,
# Nearest to be: noted, can, this, involve, it, boot, additionally, tractable,
# Nearest to in: the, and, which, of, to, from, as, for,
# Nearest to no: rif, battlezone, duplicate, clos, longinus, incapable, snes, jewellery,
# Nearest to accepted: precise, guarantees, panarion, ranging, inconvenient, alemannic, discussion, pappus,
# Nearest to freedom: freedoms, free, deletion, nascar, handler, olympiad, sensations, caribbean,
# Nearest to file: contents, epistemic, quotations, endianness, bitstream, ag, kyle, apostolicity,
# Nearest to resources: phosphates, natural, hydropower, penetrated, arable, inception, compose, cabbages,
# Nearest to arts: martial, styles, fis, disciplines, foundation, thai, skill, necromancy,
# Nearest to taking: geodesic, nizkor, milan, ijtihad, funding, shandy, depend, aphorisms,
# Nearest to universe: cosmology, cosmological, gravitationally, greenwood, almanac, bosons, meccan, uniformitarianism,
# Nearest to mean: solstices, from, resettlement, celsius, vint, amerindians, adamantium, explain,
# Nearest to insurance: marketing, taxes, anaheim, mollusks, bullion, materialize, septentrional, randal,
# Nearest to maximum: min, upwelling, scudetto, exceeding, timing, subservient, shoal, falls,
# Nearest to health: fda, prevention, petrochemicals, tudor, institutes, epa, opiates, research,
# Nearest to medical: ibuprofen, treatment, surgeon, hospitals, differentiate, calumet, doctors, stimulant,
# Nearest to coverage: assessment, news, filmmakers, extensive, report, quentin, clearinghouse, milarepa,
# Nearest to hospital: biopsy, transcaucasian, doctors, konrad, bergamo, wash, trips, curator,
# Nearest to wellness: matriculation, kupa, iud, reformed, headmaster, eyesight, dispensing, queer,
# Nearest to vaccination: convinced, tuberculosis, vocalised, apoptosis, imperative, conditional, vaccine, freedb,
# Nearest to incentive: handicrafts, pastor, obstructing, piecewise, compromises, receipt, psychoanalytical, amount,
# Nearest to car: cars, driver, prix, marvelous, cab, fuses, manufacturer, introduces,
# Nearest to house: lords, houses, revocation, evenings, commons, representatives, cardiac, room,
# Nearest to payment: retail, levied, livingston, estate, flowers, unhappy, workforce, bungalow,
# Nearest to fitness: kazimierz, eliminative, discursive, facilities, bystander, performance, uprights, disdain,
# Nearest to nutrition: lambda, referral, stearic, rhymed, cip, kennel, certificates, partei,
# Nearest to obesity: alessandri, duodenal, psychomotor, catalyzing, isoleucine, bayliss, funkadelic, prism,
# Nearest to diabetes: bangladeshis, pneumoniae, doraemons, hyperglycemia, massey, colds, mellitus, tract,
# Nearest to clinic: sidelined, venereal, ecole, crackdown, allergic, vials, liebert, piron,
# Nearest to american: states, willson, activist, latino, brent, koce, modeling, african,
# Nearest to european: member, proto, customised, europe, silverstein, esquerra, bahmani, greek,
# Epoch 7/10 Iteration: 31100 Avg. Training loss: 3.9044 0.3648 sec/batch
# Epoch 7/10 Iteration: 31200 Avg. Training loss: 3.9126 0.3620 sec/batch
# Epoch 7/10 Iteration: 31300 Avg. Training loss: 3.9197 0.3670 sec/batch
# Epoch 7/10 Iteration: 31400 Avg. Training loss: 3.9582 0.3661 sec/batch
# Epoch 7/10 Iteration: 31500 Avg. Training loss: 3.9621 0.3673 sec/batch
# Epoch 7/10 Iteration: 31600 Avg. Training loss: 3.9555 0.3696 sec/batch
# Epoch 7/10 Iteration: 31700 Avg. Training loss: 3.9033 0.3659 sec/batch
# Epoch 7/10 Iteration: 31800 Avg. Training loss: 3.8678 0.3708 sec/batch
# Epoch 7/10 Iteration: 31900 Avg. Training loss: 3.8977 0.4005 sec/batch
# Epoch 7/10 Iteration: 32000 Avg. Training loss: 3.8097 0.4097 sec/batch
# Nearest to has: the, in, and, both, bathroom, only, dek, reached,
# Nearest to such: or, characterise, lenovo, humanist, known, most, often, pasting,
# Nearest to between: polemical, the, suffixes, miniscule, continuous, bioprospecting, changeable, following,
# Nearest to some: as, and, also, the, practice, well, in, other,
# Nearest to where: lim, hydrodynamic, dada, displeased, quang, daughter, gathering, var,
# Nearest to be: noted, can, involve, this, tractable, should, boot, without,
# Nearest to in: the, and, of, which, for, has, as, from,
# Nearest to no: rif, longinus, jewellery, battlezone, clos, occ, preexistence, duplicate,
# Nearest to accepted: precise, guarantees, ranging, inconvenient, alemannic, supercontinent, handover, panarion,
# Nearest to freedom: freedoms, free, nascar, olympiad, deletion, caribbean, handler, sensations,
# Nearest to file: contents, epistemic, quotations, extensible, ag, cidr, kyle, bitstream,
# Nearest to resources: phosphates, arable, hydropower, natural, penetrated, inception, pastures, woodland,
# Nearest to arts: martial, styles, fis, thai, disciplines, advanced, skill, academy,
# Nearest to taking: geodesic, nizkor, shandy, funding, milan, ijtihad, condominiums, depend,
# Nearest to universe: cosmology, cosmological, greenwood, almanac, gravitationally, imposter, luddite, bosons,
# Nearest to mean: solstices, celsius, vint, from, amerindians, cumulative, resettlement, bigcup,
# Nearest to insurance: marketing, taxes, bullion, mollusks, anaheim, dental, materialize, abatement,
# Nearest to maximum: min, upwelling, exceeding, scudetto, subservient, falls, mailbox, timing,
# Nearest to health: fda, prevention, petrochemicals, institutes, tudor, epa, research, care,
# Nearest to medical: ibuprofen, treatment, differentiate, doctors, hospitals, surgeon, calumet, stimulant,
# Nearest to coverage: assessment, news, filmmakers, newsletter, extensive, clearinghouse, milarepa, filipinos,
# Nearest to hospital: biopsy, doctors, konrad, transcaucasian, hates, harbor, ailments, trips,
# Nearest to wellness: matriculation, iud, eyesight, headmaster, kupa, reformed, dispensing, obstetrics,
# Nearest to vaccination: convinced, tuberculosis, vocalised, apoptosis, vaccine, freedb, imperative, feb,
# Nearest to incentive: handicrafts, pastor, piecewise, compromises, obstructing, receipt, embraced, amount,
# Nearest to car: cars, driver, prix, marvelous, introduces, fuses, methodists, cab,
# Nearest to house: houses, lords, revocation, evenings, commons, representatives, donne, cardiac,
# Nearest to payment: levied, estate, retail, livingston, wish, unhappy, bungalow, legality,
# Nearest to fitness: kazimierz, eliminative, facilities, discursive, bystander, uprights, indefatigable, flyer,
# Nearest to nutrition: lambda, referral, stearic, rhymed, certificates, cip, kennel, partei,
# Nearest to obesity: alessandri, duodenal, psychomotor, catalyzing, isoleucine, bayliss, funkadelic, attenuation,
# Nearest to diabetes: bangladeshis, pneumoniae, doraemons, massey, hyperglycemia, colds, neuropathy, mellitus,
# Nearest to clinic: sidelined, venereal, vials, ecole, allergic, crackdown, piron, liebert,
# Nearest to american: states, african, koce, willson, activist, latino, modeling, nobel,
# Nearest to european: member, proto, customised, silverstein, bahmani, europe, esquerra, greek,
# Epoch 7/10 Iteration: 32100 Avg. Training loss: 3.9222 0.4148 sec/batch
# Epoch 7/10 Iteration: 32200 Avg. Training loss: 3.9087 0.4148 sec/batch
# Epoch 7/10 Iteration: 32300 Avg. Training loss: 3.8952 0.4116 sec/batch
# Epoch 8/10 Iteration: 32400 Avg. Training loss: 3.9074 0.0458 sec/batch
# Epoch 8/10 Iteration: 32500 Avg. Training loss: 3.9075 0.4288 sec/batch
# Epoch 8/10 Iteration: 32600 Avg. Training loss: 3.8843 0.4232 sec/batch
# Epoch 8/10 Iteration: 32700 Avg. Training loss: 3.8588 0.4386 sec/batch
# Epoch 8/10 Iteration: 32800 Avg. Training loss: 3.9111 0.4409 sec/batch
# Epoch 8/10 Iteration: 32900 Avg. Training loss: 3.8465 0.3901 sec/batch
# Epoch 8/10 Iteration: 33000 Avg. Training loss: 3.8514 0.4124 sec/batch
# Nearest to has: the, in, bathroom, only, both, been, and, reached,
# Nearest to such: humanist, characterise, or, lenovo, known, based, most, pasting,
# Nearest to between: polemical, suffixes, the, miniscule, aldred, changeable, continuous, offical,
# Nearest to some: as, and, also, well, practice, digimon, rhyming, restrict,
# Nearest to where: lim, displeased, hydrodynamic, quang, invited, gathering, daughter, macrinus,
# Nearest to be: involve, this, noted, can, tractable, as, additionally, termed,
# Nearest to in: the, which, and, of, from, for, as, to,
# Nearest to no: rif, jewellery, incapable, longinus, battlezone, occ, preexistence, clos,
# Nearest to accepted: precise, guarantees, inconvenient, supercontinent, ranging, panarion, alemannic, handover,
# Nearest to freedom: freedoms, free, olympiad, deletion, handler, nascar, criminalization, mahabharat,
# Nearest to file: contents, epistemic, extensible, quotations, ag, endianness, bitstream, cidr,
# Nearest to resources: hydropower, phosphates, inception, arable, forum, natural, daimlerchrysler, penetrated,
# Nearest to arts: martial, styles, skill, necromancy, disciplines, fis, thai, academy,
# Nearest to taking: milan, funding, ijtihad, nizkor, shandy, geodesic, porphyrin, mishap,
# Nearest to universe: cosmology, cosmological, greenwood, almanac, gravitationally, annihilation, comme, bosons,
# Nearest to mean: solstices, vint, amerindians, cumulative, resettlement, from, celsius, bigcup,
# Nearest to insurance: marketing, taxes, mollusks, anaheim, bullion, abatement, dental, randal,
# Nearest to maximum: min, scudetto, upwelling, exceeding, meditator, osteoporosis, subservient, shoal,
# Nearest to health: fda, prevention, petrochemicals, institutes, epa, tudor, research, care,
# Nearest to medical: ibuprofen, treatment, doctors, hospitals, surgeon, stimulant, differentiate, calumet,
# Nearest to coverage: assessment, news, filmmakers, clearinghouse, report, newsletter, milarepa, extensive,
# Nearest to hospital: biopsy, doctors, transcaucasian, konrad, bergamo, ailments, dora, hates,
# Nearest to wellness: matriculation, headmaster, iud, eyesight, involved, kupa, dispensing, rationalists,
# Nearest to vaccination: tuberculosis, convinced, vocalised, apoptosis, freedb, imperative, vaccine, feb,
# Nearest to incentive: pastor, handicrafts, piecewise, compromises, obstructing, embraced, differentiates, receipt,
# Nearest to car: cars, driver, prix, marvelous, cab, introduces, methodists, bets,
# Nearest to house: evenings, houses, lords, revocation, donne, cardiac, commons, bed,
# Nearest to payment: levied, unhappy, retail, legality, estate, wish, refused, palatinate,
# Nearest to fitness: kazimierz, eliminative, facilities, discursive, bystander, event, indefatigable, foreseen,
# Nearest to nutrition: lambda, stearic, rhymed, referral, certificates, cip, kennel, partei,
# Nearest to obesity: alessandri, duodenal, psychomotor, isoleucine, catalyzing, funkadelic, bayliss, attenuation,
# Nearest to diabetes: bangladeshis, hyperglycemia, doraemons, massey, pneumoniae, neuropathy, colds, dementia,
# Nearest to clinic: sidelined, venereal, vials, crackdown, allergic, ecole, piron, liebert,
# Nearest to american: states, activist, born, koce, latino, physiologist, willson, african,
# Nearest to european: member, proto, silverstein, customised, europe, esquerra, greek, bahmani,
# Epoch 8/10 Iteration: 33100 Avg. Training loss: 3.8581 0.4567 sec/batch
# Epoch 8/10 Iteration: 33200 Avg. Training loss: 3.8844 0.4334 sec/batch
# Epoch 8/10 Iteration: 33300 Avg. Training loss: 3.8883 0.4301 sec/batch
# Epoch 8/10 Iteration: 33400 Avg. Training loss: 3.9083 0.4135 sec/batch
# Epoch 8/10 Iteration: 33500 Avg. Training loss: 3.8315 0.4196 sec/batch
# Epoch 8/10 Iteration: 33600 Avg. Training loss: 3.8150 0.4463 sec/batch
# Epoch 8/10 Iteration: 33700 Avg. Training loss: 3.8175 0.4186 sec/batch
# Epoch 8/10 Iteration: 33800 Avg. Training loss: 3.8318 0.3751 sec/batch
# Epoch 8/10 Iteration: 33900 Avg. Training loss: 3.8735 0.3583 sec/batch
# Epoch 8/10 Iteration: 34000 Avg. Training loss: 3.9076 0.3617 sec/batch
# Nearest to has: the, in, only, both, and, are, it, bathroom,
# Nearest to such: or, humanist, be, of, based, most, characterise, known,
# Nearest to between: the, polemical, suffixes, relationship, miniscule, following, discontinuities, continuous,
# Nearest to some: and, as, also, well, to, the, rhyming, a,
# Nearest to where: lim, hydrodynamic, displeased, quang, invited, gathering, kbyte, dada,
# Nearest to be: can, this, is, to, tractable, noted, it, as,
# Nearest to in: the, which, and, for, of, to, as, from,
# Nearest to no: rif, longinus, incapable, jewellery, will, preexistence, battlezone, than,
# Nearest to accepted: precise, guarantees, inconvenient, panarion, alemannic, supercontinent, staying, pappus,
# Nearest to freedom: freedoms, free, nascar, olympiad, handler, mahabharat, criminalization, communism,
# Nearest to file: contents, epistemic, extensible, quotations, ag, endianness, cidr, repeat,
# Nearest to resources: hydropower, phosphates, arable, forum, natural, penetrated, ftp, inception,
# Nearest to arts: martial, academy, styles, fis, skill, necromancy, thai, brazilian,
# Nearest to taking: ijtihad, geodesic, milan, depend, porphyrin, funding, require, eponymous,
# Nearest to universe: cosmology, cosmological, gravitationally, almanac, greenwood, bosons, annihilation, meccan,
# Nearest to mean: solstices, from, celsius, cumulative, resettlement, amerindians, vint, accidentally,
# Nearest to insurance: marketing, taxes, mollusks, anaheim, bullion, materialize, randal, abatement,
# Nearest to maximum: min, scudetto, meditator, upwelling, exceeding, subservient, shoal, bobble,
# Nearest to health: fda, prevention, petrochemicals, infectious, epa, research, institutes, tudor,
# Nearest to medical: ibuprofen, hospitals, surgeon, treatment, doctors, clara, differentiate, calumet,
# Nearest to coverage: assessment, news, filmmakers, clearinghouse, extensive, milarepa, newsletter, weekly,
# Nearest to hospital: biopsy, doctors, transcaucasian, konrad, bergamo, ailments, dora, curator,
# Nearest to wellness: matriculation, iud, headmaster, kupa, dispensing, eyesight, involved, reformed,
# Nearest to vaccination: tuberculosis, convinced, apoptosis, vocalised, freedb, conditional, imperative, vaccine,
# Nearest to incentive: pastor, handicrafts, obstructing, piecewise, compromises, embraced, amount, receipt,
# Nearest to car: cars, driver, prix, marvelous, introduces, fuses, cab, aerom,
# Nearest to house: lords, evenings, houses, revocation, commons, cardiac, donne, representatives,
# Nearest to payment: unhappy, levied, retail, estate, wish, refused, vab, legality,
# Nearest to fitness: kazimierz, facilities, eliminative, discursive, event, bystander, indefatigable, parklands,
# Nearest to nutrition: lambda, stearic, referral, rhymed, cip, neuroscience, certificates, partei,
# Nearest to obesity: duodenal, alessandri, psychomotor, catalyzing, isoleucine, bayliss, attenuation, funkadelic,
# Nearest to diabetes: bangladeshis, hyperglycemia, doraemons, massey, pneumoniae, neuropathy, colds, mellitus,
# Nearest to clinic: sidelined, venereal, vials, ecole, crackdown, piron, allergic, midyear,
# Nearest to american: states, latino, african, koce, born, decoys, hispanic, activist,
# Nearest to european: member, silverstein, proto, europe, customised, esquerra, importer, greek,
# Epoch 8/10 Iteration: 34100 Avg. Training loss: 3.8669 0.3681 sec/batch
# Epoch 8/10 Iteration: 34200 Avg. Training loss: 3.8557 0.3601 sec/batch
# Epoch 8/10 Iteration: 34300 Avg. Training loss: 3.9298 0.3837 sec/batch
# Epoch 8/10 Iteration: 34400 Avg. Training loss: 3.9065 0.4337 sec/batch
# Epoch 8/10 Iteration: 34500 Avg. Training loss: 3.8619 0.4309 sec/batch
# Epoch 8/10 Iteration: 34600 Avg. Training loss: 3.8570 0.4248 sec/batch
# Epoch 8/10 Iteration: 34700 Avg. Training loss: 3.8687 0.4255 sec/batch
# Epoch 8/10 Iteration: 34800 Avg. Training loss: 3.8913 0.4190 sec/batch
# Epoch 8/10 Iteration: 34900 Avg. Training loss: 3.8739 0.4592 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
